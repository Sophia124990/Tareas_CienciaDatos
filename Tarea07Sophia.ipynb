# %% [markdown]
# <a href="https://colab.research.google.com/github/Sophia124990/Tareas_CienciaDatos/blob/main/Tarea07Sophia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Inciso 1

# %%
#Generamos un DataFrame con los datos de los cuatro archivos
import pandas as pd

#Leemos los archivos CSV
df1 = pd.read_csv('/content/emisiones-2016.csv', header=0, sep=';', decimal='.')
df2 = pd.read_csv('/content/emisiones-2017.csv', header=0, sep=';', decimal='.')
df3 = pd.read_csv('/content/emisiones-2018.csv', header=0, sep=';', decimal='.')
df4 = pd.read_csv('/content/emisiones-2019.csv', header=0, sep=';', decimal='.')
#Combinamos los DataFrames en uno solo
#Como los archivos tienen las mismas columnas podemos concatenarlos
df_concatenado = pd.concat([df1, df2, df3, df4], ignore_index=True)

#Mostramos las primeras 5 filas para comprobar que se hayan cargado bien los datos
df_concatenado.head()
# Out:
#    PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES   D01  \
# 0         28         79         4         1  28079004_1_38  2016    1   8.0
# 1         28         79         4         1  28079004_1_38  2016    2  12.0
# 2         28         79         4         1  28079004_1_38  2016    3  11.0
# 3         28         79         4         1  28079004_1_38  2016    4   8.0
# 4         28         79         4         1  28079004_1_38  2016    5   7.0
#
#   V01   D02  ...  D27  V27  D28  V28  D29  V29   D30  V30  D31  V31
# 0   V   7.0  ...  9.0    V  7.0    V  8.0    V   9.0    V  9.0    V
# 1   V  13.0  ...  7.0    V  8.0    V  9.0    V   0.0    N  0.0    N
# 2   V  10.0  ...  8.0    V  7.0    V  8.0    V  10.0    V  8.0    V
# 3   V   9.0  ...  9.0    V  8.0    V  8.0    V   8.0    V  0.0    N
# 4   V   8.0  ...  7.0    V  7.0    V  7.0    V   7.0    V  7.0    V
#
# [5 rows x 69 columns]

# %% [markdown]
# Inciso 2

# %%
# Filtrar las columnas del DataFrame para quedarse con las columnas ESTACION, MAGNITUD, AÑO, MES y las correspondientes a los días D01, D02, etc.
columnas_deseadas = ['ESTACION', 'MAGNITUD', 'ANO', 'MES'] + [col for col in df_concatenado.columns if col.startswith('D')]
df_filtrado = df_concatenado[columnas_deseadas]

# Mostramos las primeras filas del DataFrame filtrado
df_filtrado.head()
# Out:
#    ESTACION  MAGNITUD   ANO  MES   D01   D02  D03  D04   D05  D06  ...   D22  \
# 0         4         1  2016    1   8.0   7.0  6.0  6.0   7.0  6.0  ...  10.0
# 1         4         1  2016    2  12.0  13.0  9.0  9.0  11.0  9.0  ...  11.0
# 2         4         1  2016    3  11.0  10.0  9.0  9.0   7.0  8.0  ...   8.0
# 3         4         1  2016    4   8.0   9.0  9.0  8.0   8.0  9.0  ...   8.0
# 4         4         1  2016    5   7.0   8.0  9.0  9.0   8.0  8.0  ...   7.0
#
#     D23   D24   D25   D26  D27  D28  D29   D30  D31
# 0  11.0  11.0  13.0  12.0  9.0  7.0  8.0   9.0  9.0
# 1  10.0   9.0   8.0   7.0  7.0  8.0  9.0   0.0  0.0
# 2   8.0   9.0   9.0   9.0  8.0  7.0  8.0  10.0  8.0
# 3   8.0   8.0   8.0   9.0  9.0  8.0  8.0   8.0  0.0
# 4   7.0   8.0   7.0   7.0  7.0  7.0  7.0   7.0  7.0
#
# [5 rows x 35 columns]

# %% [markdown]
# Inciso 3

# %%
#Reestructuramos el DataFrame para que los valores de los contaminantes de las columnas de los días aparezcan en una única columna
df_reestructurado = pd.melt(df_filtrado, id_vars=['ESTACION', 'MAGNITUD', 'ANO', 'MES'], value_vars=[col for col in df_filtrado.columns if col.startswith('D')], var_name='DIA', value_name='VALOR')
#Mostramos las primeras 5 filas para comprobar la información
df_reestructurado.head()
# Out:
#    ESTACION  MAGNITUD   ANO  MES  DIA  VALOR
# 0         4         1  2016    1  D01    8.0
# 1         4         1  2016    2  D01   12.0
# 2         4         1  2016    3  D01   11.0
# 3         4         1  2016    4  D01    8.0
# 4         4         1  2016    5  D01    7.0

# %% [markdown]
# Inciso 4

# %%
#Añadir una columna con la fecha a partir de la concatenación del año, el mes y el día (usar el módulo datetime)
import datetime

def crea_fecha(row):
    anno = str(row.ANO)
    mes = str(row.MES).zfill(2)

    #Como 'DIA' tiene el formato 'D01', 'D02', etc., extraemos solo el número
    dia = str(row.DIA)[1:].zfill(2)

    #Creaamos la fecha manejando los posibles errores como dia 30 con mes febrero
    try:
        fecha = datetime.date(int(anno), int(mes), int(dia))
    except ValueError:
        fecha = None  # Asignar None si la fecha no es válida
    return fecha

#Aplicamos la función para crear la columna 'FECHA'
df_reestructurado['FECHA'] = df_reestructurado.apply(crea_fecha, axis=1)

#Mostramos las primeras 5 filas para comprobar la información
df_reestructurado.head()
# Out:
#    ESTACION  MAGNITUD   ANO  MES  DIA  VALOR       FECHA
# 0         4         1  2016    1  D01    8.0  2016-01-01
# 1         4         1  2016    2  D01   12.0  2016-02-01
# 2         4         1  2016    3  D01   11.0  2016-03-01
# 3         4         1  2016    4  D01    8.0  2016-04-01
# 4         4         1  2016    5  D01    7.0  2016-05-01

# %% [markdown]
# Inciso 5

# %%
#Eliminar las filas con fechas no válidas (utilizar la función isnat del módulo numpy)
#y ordenar el DataFrame por estaciones contaminantes y fecha
import numpy as np

#Eliminamos las filas con fechas no válidas
df_reestructurado = df_reestructurado.dropna(subset=['FECHA'])

#Ordenamos el DataFrame por estaciones contaminantes y fecha
df_reestructurado = df_reestructurado.sort_values(by=['ESTACION', 'MAGNITUD','FECHA'])

#Mostramos las primeras 5 filas para comprobar la información
df_reestructurado.head()
# Out:
#        ESTACION  MAGNITUD   ANO  MES  DIA  VALOR       FECHA
# 0             4         1  2016    1  D01    8.0  2016-01-01
# 7266          4         1  2016    1  D02    7.0  2016-01-02
# 14532         4         1  2016    1  D03    6.0  2016-01-03
# 21798         4         1  2016    1  D04    6.0  2016-01-04
# 29064         4         1  2016    1  D05    7.0  2016-01-05

# %% [markdown]
# Inciso 6

# %%
#Mostrar por pantalla las estaciones y los contaminantes disponibles en el DataFrame

estaciones = df_reestructurado['ESTACION'].unique()
contaminantes = df_reestructurado['MAGNITUD'].unique()

# Mostramos las estaciones
print("Estaciones:")
for estacion in estaciones:
  print(estacion)

# Mostramos los contaminantes
print("\nContaminantes:")
for contaminante in contaminantes:
  print(contaminante)
# Out:
# Estaciones:
# 4
# 8
# 11
# 16
# 17
# 18
# 24
# 27
# 35
# 36
# 38
# 39
# 40
# 47
# 48
# 49
# 50
# 54
# 55
# 56
# 57
# 58
# 59
# 60
#
# Contaminantes:
# 1
# 6
# 7
# 8
# 12
# 9
# 10
# 14
# 20
# 30
# 35
# 42
# 43
# 44

# %% [markdown]
# Inciso 7

# %%
# Crear una función que reciba una estación, un contaminante y un rango de fechas
#y devuelva una serie con las emisiones del contaminante dado en la estación y rango de fechas dado
#Eliminamos las filas con fechas no válidas
df_reestructurado = df_reestructurado.dropna(subset=['FECHA'])

#Ordenamos el DataFrame por estaciones contaminantes y fecha
df_reestructurado = df_reestructurado.sort_values(by=['ESTACION', 'MAGNITUD','FECHA'])

# Seleccionamos las columnas deseadas
df_reestructurado = df_reestructurado[['ESTACION', 'MAGNITUD', 'FECHA']]

#Mostramos las primeras 5 filas para comprobar la información
df_reestructurado.head()
# Out:
#        ESTACION  MAGNITUD       FECHA
# 0             4         1  2016-01-01
# 7266          4         1  2016-01-02
# 14532         4         1  2016-01-03
# 21798         4         1  2016-01-04
# 29064         4         1  2016-01-05

# %% [markdown]
# Inciso 8

# %%
#Mostrar un resumen descriptivo (mínimo, máximo, media, etc.) para cada contaminante
# Agrupamos por contaminante y calcular el resumen descriptivo
resumen_contaminantes = df_reestructurado.groupby('MAGNITUD')['VALOR'].describe()

# Mostramos el resumen
print(resumen_contaminantes)
# Out:
#             count       mean         std   min    25%    50%    75%       max
# MAGNITUD
# 1         14610.0   7.428953    7.012504  0.00   4.00   7.00  10.00    610.00
# 6         14610.0   0.350233    0.215935  0.00   0.20   0.30   0.40     14.90
# 7         35064.0  20.446412  135.123509  0.00   4.00   9.00  23.00  24742.00
# 8         35064.0  37.677618   20.118050  0.00  22.00  35.00  50.00    148.00
# 9          8948.0  10.087729   10.643591  0.00   6.00   9.00  13.00    850.00
# 10        17897.0  18.772923   35.723619  0.00  10.00  16.00  24.00   4481.00
# 12        35064.0  67.959417   61.443940  0.00  29.00  48.00  84.00   1005.00
# 14        20454.0  49.941772   24.753120  0.00  31.00  52.00  69.00    336.00
# 20         8766.0   2.364944    4.236706  0.00   0.80   1.60   2.80    195.00
# 30         8766.0   0.531371    0.538180  0.00   0.20   0.40   0.70     15.10
# 35         8766.0   0.479751    1.183618  0.00   0.10   0.20   0.50     35.70
# ...

# %%
#count: El número de valores no nulos en la columna.
#mean: La media (promedio) de los valores de la columna.
#std: La desviación estándar, que mide la dispersión de los datos con respecto a la media.
#min: El valor mínimo en la columna.
#25%: El primer cuartil (percentil 25), que es el valor por debajo del cual se encuentra el 25% de los datos.
#50%: La mediana (percentil 50), que es el valor que separa los datos en dos mitades.
#75%: El tercer cuartil (percentil 75), que es el valor por debajo del cual se encuentra el 75% de los datos.
#max: El valor máximo en la columna.

# %% [markdown]
# Inciso 9

# %%
#Mostrar un resumen descriptivo para cada contaminante por distritos
#Agrupar por distrito y contaminante y calcular el resumen descriptivo
#suponiendo que el distrito = ESTACION
resumen_contaminantes = df_reestructurado.groupby(['ESTACION', 'MAGNITUD'])['VALOR'].describe()

# Mostrar el resumen
print(resumen_contaminantes)
# Out:
#                     count       mean        std  min   25%   50%    75%    max
# ESTACION MAGNITUD
# 4        1         1461.0   7.329911  16.379050  1.0   4.0   7.0    9.0  610.0
#          6         1461.0   0.411499   0.172902  0.1   0.3   0.4    0.5    1.3
#          7         1461.0  31.939767  37.667968  0.0   8.0  16.0   42.0  239.0
#          8         1461.0  44.398357  17.766063  0.0  31.0  43.0   55.0  105.0
#          12        1461.0  93.341547  72.436531  0.0  44.0  69.0  119.0  467.0
# ...                   ...        ...        ...  ...   ...   ...    ...    ...
# 60       7         1461.0  12.326489  19.593109  1.0   2.0   4.0   12.0  151.0
#          8         1461.0  31.125941  18.101896  3.0  18.0  27.0   41.0  101.0
#          10        1461.0  17.033539  12.205022  1.0   9.0  14.0   21.0  215.0
#          12        1461.0  50.023956  45.933843  6.0  22.0  33.0   60.0  328.0
#          14        1461.0  60.718001  26.309952  4.0  42.0  65.0   81.0  119.0
#
# ...

# %% [markdown]
# Inciso 10

# %%
#Crear una función que rociba una estación y un contaminante y devuelva un resumen
#descriptivo de las emisiones del contaminante indicado en la estación indicada
resumen_contaminantes = df_reestructurado.groupby(['ESTACION', 'MAGNITUD'])['VALOR'].describe()

# Mostrar el resumen
print(resumen_contaminantes)
# Out:
#                     count       mean        std  min   25%   50%    75%    max
# ESTACION MAGNITUD
# 4        1         1461.0   7.329911  16.379050  1.0   4.0   7.0    9.0  610.0
#          6         1461.0   0.411499   0.172902  0.1   0.3   0.4    0.5    1.3
#          7         1461.0  31.939767  37.667968  0.0   8.0  16.0   42.0  239.0
#          8         1461.0  44.398357  17.766063  0.0  31.0  43.0   55.0  105.0
#          12        1461.0  93.341547  72.436531  0.0  44.0  69.0  119.0  467.0
# ...                   ...        ...        ...  ...   ...   ...    ...    ...
# 60       7         1461.0  12.326489  19.593109  1.0   2.0   4.0   12.0  151.0
#          8         1461.0  31.125941  18.101896  3.0  18.0  27.0   41.0  101.0
#          10        1461.0  17.033539  12.205022  1.0   9.0  14.0   21.0  215.0
#          12        1461.0  50.023956  45.933843  6.0  22.0  33.0   60.0  328.0
#          14        1461.0  60.718001  26.309952  4.0  42.0  65.0   81.0  119.0
#
# ...

# %% [markdown]
# Inciso 11

# %%
#Crear una función que devuelva las emisiones medias mensuales de un contaminante y un año dados para todas las estaciones

# %%
import pandas as pd

def emisiones_medias_mensuales(df, contaminante, año):
    # Convertir la columna 'FECHA' a formato datetime si no lo está
    if df['FECHA'].dtype != 'datetime64[ns]':
        df['FECHA'] = pd.to_datetime(df['FECHA'])

    # Filtrar por contaminante y año
    df_filtrado = df[(df['MAGNITUD'] == contaminante) & (df['FECHA'].dt.year == año)]

    # Añadir columna de mes para agrupar
    df_filtrado['MES'] = df_filtrado['FECHA'].dt.month

    # Agrupar por estación y mes y calcular la media de las emisiones
    emisiones_medias = df_filtrado.groupby(['ESTACION', 'MES'])['VALOR'].mean().reset_index()

    # Renombrar la columna de la media para mayor claridad
    emisiones_medias.rename(columns={'VALOR': 'EMISION_MEDIA_MENSUAL'}, inplace=True)

    # Imprimir las primeras 5 filas del resultado
    print(emisiones_medias.head())

    return emisiones_medias

# %% [markdown]
# Inciso 12

# %%
#Crear una función que reciba una estación de medición y devuelva un DataFrame con las medias mensuales de los distintos tipos de contaminante
import pandas as pd

def medias_mensuales_por_contaminante(df, estacion):
    # Convertir la columna 'FECHA' a formato datetime si no lo está
    if df['FECHA'].dtype != 'datetime64[ns]':
        df['FECHA'] = pd.to_datetime(df['FECHA'])

    # Filtrar los datos por la estación de medición
    df_filtrado = df[df['ESTACION'] == estacion]

    # Añadir columna de mes para agrupar
    df_filtrado['MES'] = df_filtrado['FECHA'].dt.month

    # Agrupar por contaminante y mes, y calcular la media de las emisiones
    medias_mensuales = df_filtrado.groupby(['MAGNITUD', 'MES'])['VALOR'].mean().reset_index()

    # Renombrar la columna de la media para mayor claridad
    medias_mensuales.rename(columns={'VALOR': 'EMISION_MEDIA_MENSUAL'}, inplace=True)

    # Imprimir las primeras 5 filas del resultado
    print(medias_mensuales.head())

    return medias_mensuales
